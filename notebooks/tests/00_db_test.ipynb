# %% [markdown]
# Hier wird getestet, ob eine Verbindung zur Datenbank aufgebaut werden kann.

# %%
import os, sys
print(os.getcwd())
print(sys.path[:5])
# Out:
# /Users/markus/Projekte/ModellingPatientHistories/notebooks/tests
# ['/opt/anaconda3/envs/thesis/lib/python313.zip', '/opt/anaconda3/envs/thesis/lib/python3.13', '/opt/anaconda3/envs/thesis/lib/python3.13/lib-dynload', '', '/opt/anaconda3/envs/thesis/lib/python3.13/site-packages']

# %%
from mph.db import get_engine
from sqlalchemy import text

engine = get_engine()
with engine.connect() as con:
    print(con.execute(text("select 1")).scalar())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mph.db import get_engine
#       2 from sqlalchemy import text
#       4 engine = get_engine()
#
# ModuleNotFoundError: No module named 'mph'
